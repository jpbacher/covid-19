# %%
import warnings
warnings.filterwarnings('ignore')
from src.get_data import Covid

# %%
covid = Covid()
# Out:
# Today is 2020-03-31

# %%
covid.update_state()
# Out:
# retrieving content...
# process completed...

# %%
covid.quick_look()
# Out:
# first five rows of state-wide data:
# ************************************************
#         date       state  fips  cases  deaths
# 0 2020-01-21  Washington    53      1       0
# 1 2020-01-22  Washington    53      1       0
# 2 2020-01-23  Washington    53      1       0
# 3 2020-01-24    Illinois    17      1       0
# 4 2020-01-24  Washington    53      1       0
#
# Number of instances: 1554

# %%
covid.process_data()
# Out:
# processing data......
# process complete......
# total time: 0.089 seconds

# %%
covid.plot_state(last_30_days=True)

# %%
covid.plot_compare_states(states=['Georgia', 'Ohio'], last_30_days=True)

# %%
covid.plot_top_states(n=5)
